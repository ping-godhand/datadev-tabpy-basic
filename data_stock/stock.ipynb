# %%
import pandas as pd
import yfinance as yf

# %%
tickers = ['AAPL', 'GOOG', 'NVDA']

df = pd.DataFrame()

for ticker in tickers:
    df_temp = yf.download(ticker, start='2025-01-01', end='2026-03-19').reset_index()
    df_temp.columns = df_temp.columns.droplevel('Ticker')
    df_temp['Ticker'] = ticker
    df_temp = df_temp[['Ticker', 'Date', 'Close']]
    df = pd.concat([df, df_temp])
    
df
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Price Ticker       Date       Close
# 0       AAPL 2025-01-02  242.525162
# 1       AAPL 2025-01-03  242.037811
# 2       AAPL 2025-01-06  243.668900
# 3       AAPL 2025-01-07  240.894058
# 4       AAPL 2025-01-08  241.381409
# ..       ...        ...         ...
# 290     NVDA 2026-03-03  180.050003
# 291     NVDA 2026-03-04  183.039993
# 292     NVDA 2026-03-05  183.339996
# 293     NVDA 2026-03-06  177.820007
# 294     NVDA 2026-03-09  180.188400
#
# [885 rows x 3 columns]
